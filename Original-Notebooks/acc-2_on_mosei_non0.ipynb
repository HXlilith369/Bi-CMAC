# %%
import pickle

def load_and_preview_features(file_path, dataset_name, print_limit=5):
    """
    加载并预览特征数据，只打印正负中性标签的前若干条。
    返回所有数据（未截断）。
    """
    with open(file_path, 'rb') as file:
        features = pickle.load(file)

    print(f"\n--- {dataset_name.upper()} DATASET ---")

    count = 0
    for i, item in enumerate(features):
        label = item.get('label', 'N/A')
        if label not in ['Positive', 'Negative', 'Neutral']:
            continue

        if count < print_limit:
            video_id = item.get('video_id', 'N/A')
            clip_id = item.get('clip_id', 'N/A')
            label_1 = item.get('label_1', 'N/A')
            mode = item.get('mode', 'N/A')
            text = item.get('text', 'N/A')
            text_feature_shape = item['text_feature'].shape if 'text_feature' in item else 'N/A'
            audio_feature_shape = item['audio_feature'].shape if 'audio_feature' in item else 'N/A'
            #vision_feature_shape = item['vision_features'].shape if 'vision_features' in item else 'N/A'
            #vision_feature_shape1 = item['vision_feature_resnet'].shape if 'vision_feature_resnet' in item else 'N/A'

            print(f"Item {i}:")
            print(f"  video_id: {video_id}")
            print(f"  clip_id: {clip_id}")
            print(f"  label_1: {label_1}")
            print(f"  label: {label}")
            print(f"  mode: {mode}")
            print(f"  text: {text}")
            print(f"  text_feature_shape: {text_feature_shape}")
            print(f"  audio_feature_shape: {audio_feature_shape}")
            #print(f"  vision_feature_shape (DenseNet): {vision_feature_shape}")
            #print(f"  vision_feature_shape (ResNet): {vision_feature_shape1}")
            print("-" * 50)
            count += 1

    print(f"共加载样本数: {len(features)}（其中三类标签样本展示前 {print_limit} 条）")
    return features

# %%
train_features = load_and_preview_features('/root/autodl-tmp/train_features.pkl', 'train')
valid_features = load_and_preview_features('/root/autodl-tmp/valid_features.pkl', 'valid')
test_features = load_and_preview_features('/root/autodl-tmp/test_features.pkl', 'test')
# Out:
# --- TRAIN DATASET ---
# Item 0:
#   video_id: -3g5yACwYnA
#   clip_id: 10
#   label_1: 1.0
#   label: Positive
#   mode: train
#   text: N/A
#   text_feature_shape: (1, 50, 768)
#   audio_feature_shape: torch.Size([1, 1284, 1024])
# --------------------------------------------------
# Item 1:
#   video_id: -3g5yACwYnA
#   clip_id: 13
#   label_1: 0.6666666865348816
#   label: Positive
#   mode: train
#   text: N/A
#   text_feature_shape: (1, 19, 768)
#   audio_feature_shape: torch.Size([1, 438, 1024])
# --------------------------------------------------
# Item 2:
#   video_id: -3g5yACwYnA
#   clip_id: 3
#   label_1: 0.0
#   label: Neutral
#   mode: train
#   text: N/A
#   text_feature_shape: (1, 40, 768)
#   audio_feature_shape: torch.Size([1, 963, 1024])
# --------------------------------------------------
# Item 3:
#   video_id: -3g5yACwYnA
#   clip_id: 2
#   label_1: 0.0
#   label: Neutral
#   mode: train
#   text: N/A
#   text_feature_shape: (1, 19, 768)
#   audio_feature_shape: torch.Size([1, 711, 1024])
# --------------------------------------------------
# Item 4:
#   video_id: -3g5yACwYnA
#   clip_id: 4
#   label_1: 1.0
#   label: Positive
#   mode: train
#   text: N/A
#   text_feature_shape: (1, 41, 768)
#   audio_feature_shape: torch.Size([1, 821, 1024])
# --------------------------------------------------
# 共加载样本数: 16310（其中三类标签样本展示前 5 条）
#
# --- VALID DATASET ---
# Item 0:
#   video_id: --qXJuDtHPw
#   clip_id: 5
#   label_1: 1.0
#   label: Positive
#   mode: valid
#   text: N/A
#   text_feature_shape: (1, 21, 768)
#   audio_feature_shape: torch.Size([1, 691, 1024])
# --------------------------------------------------
# Item 1:
#   video_id: -571d8cVauQ
#   clip_id: 0
#   label_1: 0.0
#   label: Neutral
#   mode: valid
#   text: N/A
#   text_feature_shape: (1, 20, 768)
#   audio_feature_shape: torch.Size([1, 258, 1024])
# --------------------------------------------------
# Item 2:
#   video_id: -571d8cVauQ
#   clip_id: 3
#   label_1: -0.6666666865348816
#   label: Negative
#   mode: valid
#   text: N/A
#   text_feature_shape: (1, 28, 768)
#   audio_feature_shape: torch.Size([1, 588, 1024])
# --------------------------------------------------
# Item 3:
#   video_id: -571d8cVauQ
#   clip_id: 5
#   label_1: 0.3333333432674408
#   label: Positive
#   mode: valid
#   text: N/A
#   text_feature_shape: (1, 53, 768)
#   audio_feature_shape: torch.Size([1, 924, 1024])
# --------------------------------------------------
# Item 4:
#   video_id: -I_e4mIh0yE
#   clip_id: 1
#   label_1: -0.6666666865348816
#   label: Negative
#   mode: valid
#   text: N/A
#   text_feature_shape: (1, 22, 768)
#   audio_feature_shape: torch.Size([1, 538, 1024])
# --------------------------------------------------
# 共加载样本数: 1871（其中三类标签样本展示前 5 条）
#
# --- TEST DATASET ---
# Item 0:
#   video_id: -6rXp3zJ3kc
#   clip_id: 9
#   label_1: 0.3333333432674408
#   label: Positive
#   mode: test
#   text: So the answer to the question, can I contribute stock to an IRA is absolutely correct but always be mindful of the security that your using it, make sure it's safe.
#   text_feature_shape: (1, 37, 768)
#   audio_feature_shape: torch.Size([1, 1104, 1024])
# --------------------------------------------------
# Item 1:
#   video_id: -6rXp3zJ3kc
#   clip_id: 8
#   label_1: -1.0
#   label: Negative
#   mode: test
#   text: Many people are not until they get to be a older age and they realize that gosh they wasted a lot of time and money in placing bets on stock that's ultimately lost value.
#   text_feature_shape: (1, 39, 768)
#   audio_feature_shape: torch.Size([1, 828, 1024])
# --------------------------------------------------
# Item 2:
#   video_id: -6rXp3zJ3kc
#   clip_id: 3
#   label_1: 0.0
#   label: Neutral
#   mode: test
#   text: And it's a retirement future that can ultimately turned in to an income for you when you no longer have an income and you're fully retired.
#   text_feature_shape: (1, 31, 768)
#   audio_feature_shape: torch.Size([1, 734, 1024])
# --------------------------------------------------
# Item 3:
#   video_id: -9y-fZ3swSY
#   clip_id: 1
#   label_1: 1.3333333730697632
#   label: Positive
#   mode: test
#   text: It’s so nice, by giving a good example and not directly comparing it to a lady
#   text_feature_shape: (1, 22, 768)
#   audio_feature_shape: torch.Size([1, 609, 1024])
# --------------------------------------------------
# Item 4:
#   video_id: -9y-fZ3swSY
#   clip_id: 0
#   label_1: 1.0
#   label: Positive
#   mode: test
#   text: is, you can say, hey I really like baby skin, they are so soft, they don’t have any hair on their face
#   text_feature_shape: (1, 31, 768)
#   audio_feature_shape: torch.Size([1, 344, 1024])
# --------------------------------------------------
# 共加载样本数: 4659（其中三类标签样本展示前 5 条）

# %%
import numpy as np
import torch
from sklearn.preprocessing import LabelEncoder
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim

# 假设 features 已经加载并包含在内
train_data = [item for item in train_features if item['mode'] == 'train']
valid_data = [item for item in valid_features if item['mode'] == 'valid']
test_data = [item for item in test_features if item['mode'] == 'test']

# %%
del train_features, valid_features,test_features

# %%
def drop_neutral(data, neutral_value = 'Neutral'):
    return [item for item in data if item['label'] != neutral_value]

# 去掉 neutral
train_data_bin = drop_neutral(train_data)
valid_data_bin = drop_neutral(valid_data)
test_data_bin  = drop_neutral(test_data)

train_y = np.array([item['label'] for item in train_data_bin])
valid_y = np.array([item['label'] for item in valid_data_bin])
test_y = np.array([item['label'] for item in test_data_bin])



# 打印示例以验证离散化后的标签
print("Sample converted labels (train):", train_y[:500])
print("Sample converted labels (valid):", valid_y[:500])
print("Sample converted labels (test):", test_y[:500])
# Out:
# Sample converted labels (train): ['Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Negative' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Positive' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive']
# Sample converted labels (valid): ['Positive' 'Negative' 'Positive' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Negative' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Negative' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Negative' 'Negative' 'Positive'
#  'Positive' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Negative' 'Negative' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive']
# Sample converted labels (test): ['Positive' 'Negative' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Negative'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Positive' 'Positive' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Negative' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Positive' 'Negative' 'Negative' 'Negative' 'Negative' 'Positive'
#  'Positive' 'Positive' 'Positive' 'Positive' 'Positive' 'Positive'
#  'Positive' 'Positive' 'Negative' 'Positive' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Negative' 'Negative' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative']

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
# 初始化标签编码器
label_encoder = LabelEncoder()

# 对训练标签进行拟合并转换
train_Y = label_encoder.fit_transform(train_y)

# 使用相同的编码器来转换验证标签
valid_Y = label_encoder.transform(valid_y)

test_Y = label_encoder.transform(test_y)

# %%
print(test_Y)
# Out:
# [1 0 1 ... 0 1 1]

# %%
train_X_text = [item['text_feature'] for item in train_data_bin]
valid_X_text = [item['text_feature'] for item in valid_data_bin]
test_X_text = [item['text_feature'] for item in test_data_bin]

train_X_audio = [item['audio_feature'] for item in train_data_bin]
valid_X_audio = [item['audio_feature'] for item in valid_data_bin]
test_X_audio = [item['audio_feature'] for item in test_data_bin]

# %%
import torch

# 将所有特征数据放入一个字典中
text_features = {
    'train_audio': train_X_audio,
    'valid_audio': valid_X_audio,
    'test_audio': test_X_audio
}

# 遍历字典，转换为tensor并去掉维度，然后打印形状
for key, features in text_features.items():
    for i, feature in enumerate(features):
        tensor_feature = torch.tensor(feature)  # 将特征转换为tensor
        tensor_feature = tensor_feature.squeeze(0)  # 去掉大小为1的维度（假设是第一个维度）
        text_features[key][i] = tensor_feature  # 更新字典中的值
        print(f"Feature in {key} at index {i} has shape: {tensor_feature.shape}")
# Out:
# /tmp/ipykernel_16479/2523887850.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_feature = torch.tensor(feature)  # 将特征转换为tensor
# Feature in train_audio at index 0 has shape: torch.Size([1284, 1024])
# Feature in train_audio at index 1 has shape: torch.Size([438, 1024])
# Feature in train_audio at index 2 has shape: torch.Size([821, 1024])
# Feature in train_audio at index 3 has shape: torch.Size([811, 1024])
# Feature in train_audio at index 4 has shape: torch.Size([464, 1024])
# Feature in train_audio at index 5 has shape: torch.Size([591, 1024])
# Feature in train_audio at index 6 has shape: torch.Size([573, 1024])
# Feature in train_audio at index 7 has shape: torch.Size([366, 1024])
# Feature in train_audio at index 8 has shape: torch.Size([573, 1024])
# Feature in train_audio at index 9 has shape: torch.Size([668, 1024])
# Feature in test_audio at index 3632 has shape: torch.Size([651, 1024])
# Feature in test_audio at index 3633 has shape: torch.Size([618, 1024])

# %%
import torch

# 将所有特征数据放入一个字典中
text_features = {
    'train_text': train_X_text,
    'valid_text': valid_X_text,
    'test_text': test_X_text
}

# 遍历字典，转换为tensor并去掉维度，然后打印形状
for key, features in text_features.items():
    for i, feature in enumerate(features):
        tensor_feature = torch.tensor(feature)  # 将特征转换为tensor
        tensor_feature = tensor_feature.squeeze(0)  # 去掉大小为1的维度（假设是第一个维度）
        text_features[key][i] = tensor_feature  # 更新字典中的值
        print(f"Feature in {key} at index {i} has shape: {tensor_feature.shape}")
# Out:
# Feature in train_text at index 0 has shape: torch.Size([50, 768])
# Feature in train_text at index 1 has shape: torch.Size([19, 768])
# Feature in train_text at index 2 has shape: torch.Size([41, 768])
# Feature in train_text at index 3 has shape: torch.Size([30, 768])
# Feature in train_text at index 4 has shape: torch.Size([43, 768])
# Feature in train_text at index 5 has shape: torch.Size([22, 768])
# Feature in train_text at index 6 has shape: torch.Size([32, 768])
# Feature in train_text at index 7 has shape: torch.Size([20, 768])
# Feature in train_text at index 8 has shape: torch.Size([12, 768])
# Feature in train_text at index 9 has shape: torch.Size([22, 768])
# Feature in train_text at index 10 has shape: torch.Size([19, 768])
# Feature in train_text at index 11 has shape: torch.Size([25, 768])
# Feature in train_text at index 12 has shape: torch.Size([21, 768])
# Feature in train_text at index 13 has shape: torch.Size([19, 768])
# Feature in train_text at index 14 has shape: torch.Size([35, 768])
# Feature in train_text at index 15 has shape: torch.Size([18, 768])
# Feature in train_text at index 16 has shape: torch.Size([45, 768])
# Feature in train_text at index 17 has shape: torch.Size([44, 768])
# Feature in train_text at index 18 has shape: torch.Size([35, 768])
# Feature in train_text at index 19 has shape: torch.Size([41, 768])
# Feature in train_text at index 20 has shape: torch.Size([13, 768])
# Feature in train_text at index 21 has shape: torch.Size([34, 768])
# Feature in train_text at index 22 has shape: torch.Size([32, 768])
# Feature in train_text at index 23 has shape: torch.Size([34, 768])
# Feature in train_text at index 24 has shape: torch.Size([13, 768])
# Feature in train_text at index 25 has shape: torch.Size([11, 768])
# Feature in train_text at index 26 has shape: torch.Size([29, 768])
# Feature in train_text at index 27 has shape: torch.Size([14, 768])
# Feature in train_text at index 28 has shape: torch.Size([20, 768])
# Feature in train_text at index 29 has shape: torch.Size([19, 768])
# Feature in train_text at index 30 has shape: torch.Size([25, 768])
# Feature in train_text at index 31 has shape: torch.Size([19, 768])
# Feature in train_text at index 32 has shape: torch.Size([31, 768])
# Feature in train_text at index 33 has shape: torch.Size([13, 768])
# Feature in train_text at index 34 has shape: torch.Size([10, 768])
# Feature in train_text at index 35 has shape: torch.Size([35, 768])
# Feature in train_text at index 36 has shape: torch.Size([9, 768])
# Feature in train_text at index 37 has shape: torch.Size([41, 768])
# Feature in train_text at index 38 has shape: torch.Size([15, 768])
# Feature in train_text at index 39 has shape: torch.Size([32, 768])
# Feature in train_text at index 40 has shape: torch.Size([29, 768])
# Feature in train_text at index 41 has shape: torch.Size([29, 768])
# Feature in train_text at index 42 has shape: torch.Size([35, 768])
# Feature in train_text at index 43 has shape: torch.Size([80, 768])
# Feature in train_text at index 44 has shape: torch.Size([31, 768])
# Feature in train_text at index 45 has shape: torch.Size([18, 768])
# Feature in train_text at index 46 has shape: torch.Size([49, 768])
# Feature in train_text at index 47 has shape: torch.Size([46, 768])
# Feature in train_text at index 48 has shape: torch.Size([58, 768])
# Feature in train_text at index 49 has shape: torch.Size([30, 768])
# Feature in train_text at index 50 has shape: torch.Size([42, 768])
# Feature in train_text at index 51 has shape: torch.Size([31, 768])
# Feature in train_text at index 52 has shape: torch.Size([16, 768])
# Feature in train_text at index 53 has shape: torch.Size([27, 768])
# Feature in train_text at index 54 has shape: torch.Size([37, 768])
# Feature in train_text at index 55 has shape: torch.Size([13, 768])
# Feature in train_text at index 56 has shape: torch.Size([30, 768])
# Feature in train_text at index 57 has shape: torch.Size([19, 768])
# Feature in train_text at index 58 has shape: torch.Size([21, 768])
# Feature in train_text at index 59 has shape: torch.Size([27, 768])
# Feature in train_text at index 60 has shape: torch.Size([15, 768])
# Feature in train_text at index 61 has shape: torch.Size([16, 768])
# Feature in train_text at index 62 has shape: torch.Size([25, 768])
# Feature in train_text at index 63 has shape: torch.Size([23, 768])
# Feature in train_text at index 64 has shape: torch.Size([23, 768])
# Feature in train_text at index 65 has shape: torch.Size([82, 768])
# Feature in train_text at index 66 has shape: torch.Size([15, 768])
# Feature in train_text at index 67 has shape: torch.Size([15, 768])
# Feature in train_text at index 68 has shape: torch.Size([25, 768])
# Feature in train_text at index 69 has shape: torch.Size([18, 768])
# Feature in train_text at index 70 has shape: torch.Size([19, 768])
# Feature in train_text at index 71 has shape: torch.Size([11, 768])
# Feature in train_text at index 72 has shape: torch.Size([13, 768])
# Feature in train_text at index 73 has shape: torch.Size([16, 768])
# Feature in train_text at index 74 has shape: torch.Size([7, 768])
# Feature in train_text at index 75 has shape: torch.Size([7, 768])
# Feature in train_text at index 76 has shape: torch.Size([27, 768])
# Feature in train_text at index 77 has shape: torch.Size([21, 768])
# Feature in train_text at index 78 has shape: torch.Size([37, 768])
# Feature in train_text at index 79 has shape: torch.Size([31, 768])
# Feature in train_text at index 80 has shape: torch.Size([45, 768])
# Feature in train_text at index 81 has shape: torch.Size([30, 768])
# Feature in train_text at index 82 has shape: torch.Size([23, 768])
# Feature in train_text at index 83 has shape: torch.Size([49, 768])
# Feature in train_text at index 84 has shape: torch.Size([16, 768])
# Feature in train_text at index 85 has shape: torch.Size([7, 768])
# Feature in train_text at index 86 has shape: torch.Size([13, 768])
# Feature in train_text at index 87 has shape: torch.Size([23, 768])
# Feature in train_text at index 88 has shape: torch.Size([17, 768])
# Feature in train_text at index 89 has shape: torch.Size([53, 768])
# Feature in train_text at index 90 has shape: torch.Size([32, 768])
# Feature in train_text at index 91 has shape: torch.Size([29, 768])
# Feature in train_text at index 92 has shape: torch.Size([77, 768])
# Feature in train_text at index 93 has shape: torch.Size([20, 768])
# Feature in train_text at index 94 has shape: torch.Size([27, 768])
# Feature in train_text at index 95 has shape: torch.Size([43, 768])
# Feature in train_text at index 96 has shape: torch.Size([29, 768])
# Feature in train_text at index 97 has shape: torch.Size([30, 768])
# Feature in train_text at index 98 has shape: torch.Size([25, 768])
# Feature in train_text at index 99 has shape: torch.Size([25, 768])
# Feature in train_text at index 100 has shape: torch.Size([32, 768])
# Feature in train_text at index 101 has shape: torch.Size([14, 768])
# Feature in train_text at index 102 has shape: torch.Size([22, 768])
# Feature in train_text at index 103 has shape: torch.Size([31, 768])
# Feature in train_text at index 104 has shape: torch.Size([31, 768])
# Feature in train_text at index 105 has shape: torch.Size([24, 768])
# Feature in train_text at index 106 has shape: torch.Size([39, 768])
# Feature in train_text at index 107 has shape: torch.Size([23, 768])
# Feature in train_text at index 108 has shape: torch.Size([35, 768])
# Feature in train_text at index 109 has shape: torch.Size([34, 768])
# Feature in train_text at index 110 has shape: torch.Size([15, 768])
# Feature in train_text at index 111 has shape: torch.Size([21, 768])
# Feature in train_text at index 112 has shape: torch.Size([31, 768])
# Feature in train_text at index 113 has shape: torch.Size([24, 768])
# Feature in train_text at index 114 has shape: torch.Size([17, 768])
# Feature in train_text at index 115 has shape: torch.Size([17, 768])
# Feature in train_text at index 116 has shape: torch.Size([18, 768])
# Feature in train_text at index 117 has shape: torch.Size([13, 768])
# Feature in train_text at index 118 has shape: torch.Size([28, 768])
# Feature in train_text at index 119 has shape: torch.Size([15, 768])
# Feature in train_text at index 120 has shape: torch.Size([9, 768])
# Feature in train_text at index 121 has shape: torch.Size([26, 768])
# Feature in train_text at index 122 has shape: torch.Size([10, 768])
# Feature in train_text at index 123 has shape: torch.Size([11, 768])
# Feature in train_text at index 124 has shape: torch.Size([17, 768])
# Feature in train_text at index 125 has shape: torch.Size([8, 768])
# Feature in train_text at index 126 has shape: torch.Size([10, 768])
# Feature in train_text at index 127 has shape: torch.Size([10, 768])
# Feature in train_text at index 128 has shape: torch.Size([11, 768])
# Feature in train_text at index 129 has shape: torch.Size([19, 768])
# Feature in train_text at index 130 has shape: torch.Size([10, 768])
# Feature in train_text at index 131 has shape: torch.Size([11, 768])
# Feature in train_text at index 132 has shape: torch.Size([9, 768])
# Feature in train_text at index 133 has shape: torch.Size([18, 768])
# Feature in train_text at index 134 has shape: torch.Size([27, 768])
# Feature in train_text at index 135 has shape: torch.Size([28, 768])
# Feature in train_text at index 136 has shape: torch.Size([17, 768])
# Feature in train_text at index 137 has shape: torch.Size([19, 768])
# Feature in train_text at index 138 has shape: torch.Size([17, 768])
# Feature in train_text at index 139 has shape: torch.Size([22, 768])
# Feature in train_text at index 140 has shape: torch.Size([20, 768])
# Feature in train_text at index 141 has shape: torch.Size([36, 768])
# Feature in train_text at index 142 has shape: torch.Size([13, 768])
# Feature in train_text at index 143 has shape: torch.Size([29, 768])
# Feature in train_text at index 144 has shape: torch.Size([40, 768])
# Feature in train_text at index 145 has shape: torch.Size([21, 768])
# Feature in train_text at index 146 has shape: torch.Size([32, 768])
# Feature in train_text at index 147 has shape: torch.Size([35, 768])
# Feature in train_text at index 148 has shape: torch.Size([36, 768])
# Feature in train_text at index 149 has shape: torch.Size([15, 768])
# Feature in train_text at index 150 has shape: torch.Size([34, 768])
# Feature in train_text at index 151 has shape: torch.Size([24, 768])
# Feature in train_text at index 152 has shape: torch.Size([17, 768])
# Feature in train_text at index 153 has shape: torch.Size([28, 768])
# Feature in train_text at index 154 has shape: torch.Size([44, 768])
# Feature in train_text at index 155 has shape: torch.Size([43, 768])
# Feature in train_text at index 156 has shape: torch.Size([27, 768])
# Feature in train_text at index 157 has shape: torch.Size([38, 768])
# Feature in train_text at index 158 has shape: torch.Size([22, 768])
# Feature in train_text at index 159 has shape: torch.Size([25, 768])
# Feature in train_text at index 160 has shape: torch.Size([19, 768])
# Feature in train_text at index 161 has shape: torch.Size([34, 768])
# Feature in train_text at index 162 has shape: torch.Size([21, 768])
# Feature in train_text at index 163 has shape: torch.Size([18, 768])
# Feature in train_text at index 164 has shape: torch.Size([28, 768])
# Feature in train_text at index 165 has shape: torch.Size([17, 768])
# Feature in train_text at index 166 has shape: torch.Size([18, 768])
# Feature in train_text at index 167 has shape: torch.Size([27, 768])
# Feature in train_text at index 168 has shape: torch.Size([18, 768])
# Feature in train_text at index 169 has shape: torch.Size([19, 768])
# Feature in train_text at index 170 has shape: torch.Size([36, 768])
# Feature in train_text at index 171 has shape: torch.Size([17, 768])
# Feature in train_text at index 172 has shape: torch.Size([8, 768])
# Feature in train_text at index 173 has shape: torch.Size([13, 768])
# Feature in train_text at index 174 has shape: torch.Size([15, 768])
# Feature in train_text at index 175 has shape: torch.Size([37, 768])
# Feature in train_text at index 176 has shape: torch.Size([14, 768])
# Feature in train_text at index 177 has shape: torch.Size([24, 768])
# Feature in train_text at index 178 has shape: torch.Size([14, 768])
# Feature in train_text at index 179 has shape: torch.Size([16, 768])
# Feature in train_text at index 180 has shape: torch.Size([12, 768])
# Feature in train_text at index 181 has shape: torch.Size([39, 768])
# Feature in train_text at index 182 has shape: torch.Size([28, 768])
# Feature in train_text at index 183 has shape: torch.Size([32, 768])
# Feature in train_text at index 184 has shape: torch.Size([17, 768])
# Feature in train_text at index 185 has shape: torch.Size([8, 768])
# Feature in train_text at index 186 has shape: torch.Size([86, 768])
# Feature in train_text at index 187 has shape: torch.Size([12, 768])
# Feature in train_text at index 188 has shape: torch.Size([28, 768])
# Feature in train_text at index 189 has shape: torch.Size([24, 768])
# Feature in train_text at index 190 has shape: torch.Size([43, 768])
# Feature in train_text at index 191 has shape: torch.Size([12, 768])
# Feature in train_text at index 192 has shape: torch.Size([16, 768])
# Feature in train_text at index 193 has shape: torch.Size([19, 768])
# Feature in train_text at index 194 has shape: torch.Size([64, 768])
# Feature in train_text at index 195 has shape: torch.Size([19, 768])
# Feature in train_text at index 196 has shape: torch.Size([17, 768])
# Feature in train_text at index 197 has shape: torch.Size([9, 768])
# Feature in train_text at index 198 has shape: torch.Size([37, 768])
# Feature in train_text at index 199 has shape: torch.Size([7, 768])
# Feature in train_text at index 200 has shape: torch.Size([33, 768])
# Feature in train_text at index 201 has shape: torch.Size([17, 768])
# Feature in train_text at index 202 has shape: torch.Size([19, 768])
# Feature in train_text at index 203 has shape: torch.Size([90, 768])
# Feature in train_text at index 204 has shape: torch.Size([67, 768])
# Feature in train_text at index 205 has shape: torch.Size([70, 768])
# Feature in train_text at index 206 has shape: torch.Size([24, 768])
# Feature in train_text at index 207 has shape: torch.Size([39, 768])
# Feature in train_text at index 208 has shape: torch.Size([33, 768])
# Feature in train_text at index 209 has shape: torch.Size([20, 768])
# Feature in train_text at index 210 has shape: torch.Size([85, 768])
# Feature in train_text at index 211 has shape: torch.Size([22, 768])
# Feature in train_text at index 212 has shape: torch.Size([60, 768])
# Feature in train_text at index 213 has shape: torch.Size([21, 768])
# Feature in train_text at index 214 has shape: torch.Size([34, 768])
# Feature in train_text at index 215 has shape: torch.Size([28, 768])
# Feature in train_text at index 216 has shape: torch.Size([32, 768])
# Feature in train_text at index 217 has shape: torch.Size([21, 768])
# Feature in train_text at index 218 has shape: torch.Size([9, 768])
# Feature in train_text at index 219 has shape: torch.Size([19, 768])
# Feature in train_text at index 220 has shape: torch.Size([43, 768])
# Feature in train_text at index 221 has shape: torch.Size([13, 768])
# Feature in train_text at index 222 has shape: torch.Size([12, 768])
# Feature in train_text at index 223 has shape: torch.Size([18, 768])
# Feature in train_text at index 224 has shape: torch.Size([38, 768])
# Feature in train_text at index 225 has shape: torch.Size([11, 768])
# Feature in train_text at index 226 has shape: torch.Size([32, 768])
# Feature in train_text at index 227 has shape: torch.Size([33, 768])
# Feature in train_text at index 228 has shape: torch.Size([37, 768])
# Feature in train_text at index 229 has shape: torch.Size([27, 768])
# Feature in train_text at index 230 has shape: torch.Size([28, 768])
# Feature in train_text at index 231 has shape: torch.Size([20, 768])
# Feature in train_text at index 232 has shape: torch.Size([22, 768])
# Feature in train_text at index 233 has shape: torch.Size([20, 768])
# Feature in train_text at index 234 has shape: torch.Size([17, 768])
# Feature in train_text at index 235 has shape: torch.Size([23, 768])
# Feature in train_text at index 236 has shape: torch.Size([9, 768])
# Feature in train_text at index 237 has shape: torch.Size([22, 768])
# Feature in train_text at index 238 has shape: torch.Size([8, 768])
# Feature in train_text at index 239 has shape: torch.Size([12, 768])
# Feature in train_text at index 240 has shape: torch.Size([33, 768])
# Feature in train_text at index 241 has shape: torch.Size([34, 768])
# Feature in train_text at index 242 has shape: torch.Size([14, 768])
# Feature in train_text at index 243 has shape: torch.Size([31, 768])
# Feature in train_text at index 244 has shape: torch.Size([21, 768])
# Feature in train_text at index 245 has shape: torch.Size([21, 768])
# Feature in train_text at index 246 has shape: torch.Size([31, 768])
# Feature in train_text at index 247 has shape: torch.Size([4, 768])
# Feature in train_text at index 248 has shape: torch.Size([51, 768])
# Feature in train_text at index 249 has shape: torch.Size([25, 768])
# Feature in train_text at index 250 has shape: torch.Size([88, 768])
# Feature in train_text at index 251 has shape: torch.Size([31, 768])
# Feature in train_text at index 252 has shape: torch.Size([60, 768])
# Feature in train_text at index 253 has shape: torch.Size([34, 768])
# Feature in train_text at index 254 has shape: torch.Size([19, 768])
# Feature in train_text at index 255 has shape: torch.Size([5, 768])
# Feature in train_text at index 256 has shape: torch.Size([9, 768])
# Feature in train_text at index 257 has shape: torch.Size([30, 768])
# Feature in train_text at index 258 has shape: torch.Size([18, 768])
# Feature in train_text at index 259 has shape: torch.Size([17, 768])
# Feature in train_text at index 260 has shape: torch.Size([24, 768])
# Feature in train_text at index 261 has shape: torch.Size([69, 768])
# Feature in train_text at index 262 has shape: torch.Size([31, 768])
# Feature in train_text at index 263 has shape: torch.Size([9, 768])
# Feature in train_text at index 264 has shape: torch.Size([18, 768])
# Feature in train_text at index 265 has shape: torch.Size([19, 768])
# Feature in train_text at index 266 has shape: torch.Size([13, 768])
# Feature in train_text at index 267 has shape: torch.Size([44, 768])
# Feature in train_text at index 268 has shape: torch.Size([27, 768])
# Feature in train_text at index 269 has shape: torch.Size([20, 768])
# Feature in train_text at index 270 has shape: torch.Size([19, 768])
# Feature in train_text at index 271 has shape: torch.Size([35, 768])
# Feature in train_text at index 272 has shape: torch.Size([22, 768])
# Feature in train_text at index 273 has shape: torch.Size([45, 768])
# Feature in train_text at index 274 has shape: torch.Size([21, 768])
# Feature in train_text at index 275 has shape: torch.Size([33, 768])
# Feature in train_text at index 276 has shape: torch.Size([113, 768])
# Feature in train_text at index 277 has shape: torch.Size([62, 768])
# Feature in train_text at index 278 has shape: torch.Size([15, 768])
# Feature in train_text at index 279 has shape: torch.Size([16, 768])
# Feature in train_text at index 280 has shape: torch.Size([51, 768])
# Feature in train_text at index 281 has shape: torch.Size([22, 768])
# Feature in train_text at index 282 has shape: torch.Size([22, 768])
# Feature in train_text at index 283 has shape: torch.Size([17, 768])
# Feature in train_text at index 284 has shape: torch.Size([18, 768])
# Feature in train_text at index 285 has shape: torch.Size([76, 768])
# Feature in train_text at index 286 has shape: torch.Size([14, 768])
# Feature in train_text at index 287 has shape: torch.Size([63, 768])
# Feature in train_text at index 288 has shape: torch.Size([11, 768])
# Feature in train_text at index 289 has shape: torch.Size([18, 768])
# Feature in train_text at index 290 has shape: torch.Size([50, 768])
# Feature in train_text at index 291 has shape: torch.Size([14, 768])
# Feature in train_text at index 292 has shape: torch.Size([25, 768])
# Feature in train_text at index 293 has shape: torch.Size([21, 768])
# Feature in train_text at index 294 has shape: torch.Size([29, 768])
# Feature in train_text at index 295 has shape: torch.Size([11, 768])
# Feature in train_text at index 296 has shape: torch.Size([15, 768])
# Feature in train_text at index 297 has shape: torch.Size([22, 768])
# Feature in train_text at index 298 has shape: torch.Size([16, 768])
# Feature in train_text at index 299 has shape: torch.Size([6, 768])
# Feature in train_text at index 300 has shape: torch.Size([30, 768])
# Feature in train_text at index 301 has shape: torch.Size([12, 768])
# Feature in train_text at index 302 has shape: torch.Size([12, 768])
# Feature in train_text at index 303 has shape: torch.Size([15, 768])
# Feature in train_text at index 304 has shape: torch.Size([27, 768])
# Feature in train_text at index 305 has shape: torch.Size([22, 768])
# Feature in train_text at index 306 has shape: torch.Size([21, 768])
# Feature in train_text at index 307 has shape: torch.Size([13, 768])
# Feature in train_text at index 308 has shape: torch.Size([16, 768])
# Feature in train_text at index 309 has shape: torch.Size([26, 768])
# Feature in train_text at index 310 has shape: torch.Size([12, 768])
# Feature in train_text at index 311 has shape: torch.Size([13, 768])
# Feature in train_text at index 312 has shape: torch.Size([12, 768])
# Feature in train_text at index 313 has shape: torch.Size([21, 768])
# Feature in train_text at index 314 has shape: torch.Size([22, 768])
# Feature in train_text at index 315 has shape: torch.Size([34, 768])
# Feature in train_text at index 316 has shape: torch.Size([16, 768])
# Feature in train_text at index 317 has shape: torch.Size([16, 768])
# Feature in train_text at index 318 has shape: torch.Size([6, 768])
# Feature in train_text at index 319 has shape: torch.Size([26, 768])
# Feature in train_text at index 320 has shape: torch.Size([7, 768])
# Feature in train_text at index 321 has shape: torch.Size([31, 768])
# Feature in train_text at index 322 has shape: torch.Size([27, 768])
# Feature in train_text at index 323 has shape: torch.Size([14, 768])
# Feature in train_text at index 324 has shape: torch.Size([29, 768])
# Feature in train_text at index 325 has shape: torch.Size([13, 768])
# Feature in train_text at index 326 has shape: torch.Size([23, 768])
# Feature in train_text at index 327 has shape: torch.Size([12, 768])
# Feature in train_text at index 328 has shape: torch.Size([19, 768])
# Feature in train_text at index 329 has shape: torch.Size([12, 768])
# Feature in train_text at index 330 has shape: torch.Size([13, 768])
# Feature in train_text at index 331 has shape: torch.Size([35, 768])
# Feature in train_text at index 332 has shape: torch.Size([76, 768])
# Feature in train_text at index 333 has shape: torch.Size([52, 768])
# Feature in train_text at index 334 has shape: torch.Size([16, 768])
# Feature in train_text at index 335 has shape: torch.Size([10, 768])
# Feature in train_text at index 336 has shape: torch.Size([29, 768])
# Feature in train_text at index 337 has shape: torch.Size([14, 768])
# Feature in train_text at index 338 has shape: torch.Size([24, 768])
# Feature in train_text at index 339 has shape: torch.Size([63, 768])
# Feature in train_text at index 340 has shape: torch.Size([53, 768])
# Feature in train_text at index 341 has shape: torch.Size([68, 768])
# Feature in train_text at index 342 has shape: torch.Size([11, 768])
# Feature in train_text at index 343 has shape: torch.Size([36, 768])
# Feature in train_text at index 344 has shape: torch.Size([34, 768])
# Feature in train_text at index 345 has shape: torch.Size([28, 768])
# Feature in train_text at index 346 has shape: torch.Size([20, 768])
# Feature in train_text at index 347 has shape: torch.Size([25, 768])
# Feature in train_text at index 348 has shape: torch.Size([76, 768])
# Feature in train_text at index 349 has shape: torch.Size([44, 768])
# Feature in train_text at index 350 has shape: torch.Size([21, 768])
# Feature in train_text at index 351 has shape: torch.Size([10, 768])
# Feature in train_text at index 352 has shape: torch.Size([5, 768])
# Feature in train_text at index 353 has shape: torch.Size([17, 768])
# Feature in train_text at index 354 has shape: torch.Size([17, 768])
# Feature in train_text at index 355 has shape: torch.Size([33, 768])
# Feature in train_text at index 356 has shape: torch.Size([30, 768])
# Feature in train_text at index 357 has shape: torch.Size([32, 768])
# Feature in train_text at index 358 has shape: torch.Size([14, 768])
# Feature in train_text at index 359 has shape: torch.Size([24, 768])
# Feature in train_text at index 360 has shape: torch.Size([37, 768])
# Feature in train_text at index 361 has shape: torch.Size([20, 768])
# Feature in train_text at index 362 has shape: torch.Size([36, 768])
# Feature in train_text at index 363 has shape: torch.Size([15, 768])
# Feature in train_text at index 364 has shape: torch.Size([29, 768])
# Feature in train_text at index 365 has shape: torch.Size([9, 768])
# Feature in train_text at index 366 has shape: torch.Size([18, 768])
# Feature in train_text at index 367 has shape: torch.Size([27, 768])
# Feature in train_text at index 368 has shape: torch.Size([19, 768])
# Feature in train_text at index 369 has shape: torch.Size([26, 768])
# Feature in train_text at index 370 has shape: torch.Size([17, 768])
# Feature in train_text at index 371 has shape: torch.Size([17, 768])
# Feature in train_text at index 372 has shape: torch.Size([28, 768])
# Feature in train_text at index 373 has shape: torch.Size([28, 768])
# Feature in train_text at index 374 has shape: torch.Size([28, 768])
# Feature in train_text at index 375 has shape: torch.Size([20, 768])
# Feature in train_text at index 376 has shape: torch.Size([18, 768])
# Feature in train_text at index 377 has shape: torch.Size([15, 768])
# Feature in train_text at index 378 has shape: torch.Size([11, 768])
# Feature in train_text at index 379 has shape: torch.Size([18, 768])
# Feature in train_text at index 380 has shape: torch.Size([8, 768])
# Feature in train_text at index 381 has shape: torch.Size([29, 768])
# Feature in train_text at index 382 has shape: torch.Size([23, 768])
# Feature in train_text at index 383 has shape: torch.Size([20, 768])
# Feature in train_text at index 384 has shape: torch.Size([21, 768])
# Feature in train_text at index 385 has shape: torch.Size([14, 768])
# Feature in train_text at index 386 has shape: torch.Size([18, 768])
# Feature in train_text at index 387 has shape: torch.Size([12, 768])
# Feature in train_text at index 388 has shape: torch.Size([11, 768])
# Feature in train_text at index 389 has shape: torch.Size([10, 768])
# Feature in train_text at index 390 has shape: torch.Size([19, 768])
# Feature in train_text at index 391 has shape: torch.Size([19, 768])
# Feature in train_text at index 392 has shape: torch.Size([15, 768])
# Feature in train_text at index 393 has shape: torch.Size([55, 768])
# Feature in train_text at index 394 has shape: torch.Size([28, 768])
# Feature in train_text at index 395 has shape: torch.Size([10, 768])
# Feature in train_text at index 396 has shape: torch.Size([7, 768])
# Feature in train_text at index 397 has shape: torch.Size([3, 768])
# Feature in train_text at index 398 has shape: torch.Size([63, 768])
# Feature in train_text at index 399 has shape: torch.Size([40, 768])
# Feature in train_text at index 400 has shape: torch.Size([7, 768])
# Feature in train_text at index 401 has shape: torch.Size([13, 768])
# Feature in train_text at index 402 has shape: torch.Size([10, 768])
# Feature in train_text at index 403 has shape: torch.Size([18, 768])
# Feature in train_text at index 404 has shape: torch.Size([22, 768])
# Feature in train_text at index 405 has shape: torch.Size([27, 768])
# Feature in train_text at index 406 has shape: torch.Size([43, 768])
# Feature in train_text at index 407 has shape: torch.Size([17, 768])
# Feature in train_text at index 408 has shape: torch.Size([25, 768])
# Feature in train_text at index 409 has shape: torch.Size([19, 768])
# Feature in train_text at index 410 has shape: torch.Size([26, 768])
# Feature in train_text at index 411 has shape: torch.Size([20, 768])
# Feature in train_text at index 412 has shape: torch.Size([12, 768])
# Feature in train_text at index 413 has shape: torch.Size([106, 768])
# Feature in train_text at index 414 has shape: torch.Size([27, 768])
# Feature in train_text at index 415 has shape: torch.Size([41, 768])
# Feature in train_text at index 416 has shape: torch.Size([13, 768])
# Feature in train_text at index 417 has shape: torch.Size([13, 768])
# Feature in train_text at index 418 has shape: torch.Size([41, 768])
# Feature in train_text at index 419 has shape: torch.Size([40, 768])
# Feature in train_text at index 420 has shape: torch.Size([14, 768])
# Feature in train_text at index 421 has shape: torch.Size([8, 768])
# Feature in train_text at index 422 has shape: torch.Size([21, 768])
# Feature in train_text at index 423 has shape: torch.Size([16, 768])
# Feature in train_text at index 424 has shape: torch.Size([26, 768])
# Feature in train_text at index 425 has shape: torch.Size([15, 768])
# Feature in train_text at index 426 has shape: torch.Size([34, 768])
# Feature in train_text at index 427 has shape: torch.Size([28, 768])
# Feature in train_text at index 428 has shape: torch.Size([16, 768])
# Feature in train_text at index 429 has shape: torch.Size([10, 768])
# Feature in train_text at index 430 has shape: torch.Size([81, 768])
# Feature in train_text at index 431 has shape: torch.Size([50, 768])
# Feature in train_text at index 432 has shape: torch.Size([9, 768])
# Feature in train_text at index 433 has shape: torch.Size([28, 768])
# Feature in train_text at index 434 has shape: torch.Size([20, 768])
# Feature in train_text at index 435 has shape: torch.Size([21, 768])
# Feature in train_text at index 436 has shape: torch.Size([9, 768])
# Feature in train_text at index 437 has shape: torch.Size([34, 768])
# Feature in train_text at index 438 has shape: torch.Size([24, 768])
# Feature in train_text at index 439 has shape: torch.Size([32, 768])
# Feature in train_text at index 440 has shape: torch.Size([92, 768])
# Feature in train_text at index 441 has shape: torch.Size([13, 768])
# Feature in train_text at index 442 has shape: torch.Size([7, 768])
# Feature in train_text at index 443 has shape: torch.Size([15, 768])
# Feature in train_text at index 444 has shape: torch.Size([19, 768])
# Feature in train_text at index 445 has shape: torch.Size([10, 768])
# Feature in train_text at index 446 has shape: torch.Size([18, 768])
# Feature in train_text at index 447 has shape: torch.Size([42, 768])
# Feature in train_text at index 448 has shape: torch.Size([22, 768])
# Feature in train_text at index 449 has shape: torch.Size([18, 768])
# Feature in train_text at index 450 has shape: torch.Size([24, 768])
# Feature in train_text at index 451 has shape: torch.Size([13, 768])
# Feature in train_text at index 452 has shape: torch.Size([27, 768])
# Feature in train_text at index 453 has shape: torch.Size([9, 768])
# Feature in train_text at index 454 has shape: torch.Size([22, 768])
# Feature in train_text at index 455 has shape: torch.Size([6, 768])
# Feature in train_text at index 456 has shape: torch.Size([24, 768])
# Feature in train_text at index 457 has shape: torch.Size([35, 768])
# Feature in train_text at index 458 has shape: torch.Size([9, 768])
# Feature in train_text at index 459 has shape: torch.Size([16, 768])
# Feature in train_text at index 460 has shape: torch.Size([23, 768])
# Feature in train_text at index 461 has shape: torch.Size([66, 768])
# Feature in train_text at index 462 has shape: torch.Size([11, 768])
# Feature in train_text at index 463 has shape: torch.Size([9, 768])
# Feature in train_text at index 464 has shape: torch.Size([11, 768])
# Feature in train_text at index 465 has shape: torch.Size([15, 768])
# Feature in train_text at index 466 has shape: torch.Size([25, 768])
# Feature in train_text at index 467 has shape: torch.Size([11, 768])
# Feature in train_text at index 468 has shape: torch.Size([22, 768])
# Feature in train_text at index 469 has shape: torch.Size([21, 768])
# Feature in train_text at index 470 has shape: torch.Size([53, 768])
# Feature in train_text at index 471 has shape: torch.Size([7, 768])
# Feature in train_text at index 472 has shape: torch.Size([19, 768])
# Feature in train_text at index 473 has shape: torch.Size([86, 768])
# Feature in train_text at index 474 has shape: torch.Size([25, 768])
# Feature in train_text at index 475 has shape: torch.Size([6, 768])
# Feature in train_text at index 476 has shape: torch.Size([6, 768])
# Feature in train_text at index 477 has shape: torch.Size([30, 768])
# Feature in train_text at index 478 has shape: torch.Size([62, 768])
# Feature in train_text at index 479 has shape: torch.Size([38, 768])
# Feature in train_text at index 480 has shape: torch.Size([30, 768])
# Feature in train_text at index 481 has shape: torch.Size([12, 768])
# Feature in train_text at index 482 has shape: torch.Size([28, 768])
# Feature in train_text at index 483 has shape: torch.Size([30, 768])
# Feature in train_text at index 484 has shape: torch.Size([10, 768])
# Feature in train_text at index 485 has shape: torch.Size([14, 768])
# Feature in train_text at index 486 has shape: torch.Size([9, 768])
# Feature in train_text at index 487 has shape: torch.Size([9, 768])
# Feature in train_text at index 488 has shape: torch.Size([7, 768])
# Feature in train_text at index 489 has shape: torch.Size([43, 768])
# Feature in train_text at index 490 has shape: torch.Size([8, 768])
# Feature in train_text at index 491 has shape: torch.Size([27, 768])
# Feature in train_text at index 492 has shape: torch.Size([30, 768])
# Feature in train_text at index 493 has shape: torch.Size([16, 768])
# Feature in train_text at index 494 has shape: torch.Size([8, 768])
# Feature in train_text at index 495 has shape: torch.Size([20, 768])
# Feature in train_text at index 496 has shape: torch.Size([35, 768])
# Feature in train_text at index 497 has shape: torch.Size([80, 768])
# Feature in train_text at index 498 has shape: torch.Size([9, 768])
# Feature in train_text at index 499 has shape: torch.Size([15, 768])
# Feature in train_text at index 500 has shape: torch.Size([10, 768])
# Feature in train_text at index 501 has shape: torch.Size([8, 768])
# Feature in train_text at index 502 has shape: torch.Size([16, 768])
# Feature in train_text at index 503 has shape: torch.Size([10, 768])
# Feature in train_text at index 504 has shape: torch.Size([27, 768])
# Feature in train_text at index 505 has shape: torch.Size([18, 768])
# Feature in train_text at index 506 has shape: torch.Size([25, 768])
# Feature in train_text at index 507 has shape: torch.Size([35, 768])
# Feature in train_text at index 508 has shape: torch.Size([14, 768])
# Feature in train_text at index 509 has shape: torch.Size([11, 768])
# Feature in train_text at index 510 has shape: torch.Size([36, 768])
# Feature in train_text at index 511 has shape: torch.Size([25, 768])
# Feature in train_text at index 512 has shape: torch.Size([29, 768])
# Feature in train_text at index 513 has shape: torch.Size([9, 768])
# Feature in train_text at index 514 has shape: torch.Size([10, 768])
# Feature in train_text at index 515 has shape: torch.Size([13, 768])
# Feature in train_text at index 516 has shape: torch.Size([10, 768])
# Feature in train_text at index 517 has shape: torch.Size([12, 768])
# Feature in train_text at index 518 has shape: torch.Size([56, 768])
# Feature in train_text at index 519 has shape: torch.Size([13, 768])
# Feature in train_text at index 520 has shape: torch.Size([22, 768])
# Feature in train_text at index 521 has shape: torch.Size([6, 768])
# Feature in train_text at index 522 has shape: torch.Size([11, 768])
# Feature in train_text at index 523 has shape: torch.Size([12, 768])
# Feature in train_text at index 524 has shape: torch.Size([14, 768])
# Feature in train_text at index 525 has shape: torch.Size([11, 768])
# Feature in train_text at index 526 has shape: torch.Size([28, 768])
# Feature in train_text at index 527 has shape: torch.Size([29, 768])
# Feature in train_text at index 528 has shape: torch.Size([20, 768])
# Feature in train_text at index 529 has shape: torch.Size([24, 768])
# Feature in train_text at index 530 has shape: torch.Size([17, 768])
# Feature in train_text at index 531 has shape: torch.Size([24, 768])
# Feature in train_text at index 532 has shape: torch.Size([25, 768])
# Feature in train_text at index 533 has shape: torch.Size([9, 768])
# Feature in train_text at index 534 has shape: torch.Size([16, 768])
# Feature in train_text at index 535 has shape: torch.Size([20, 768])
# Feature in train_text at index 536 has shape: torch.Size([16, 768])
# Feature in train_text at index 537 has shape: torch.Size([45, 768])
# Feature in train_text at index 538 has shape: torch.Size([27, 768])
# Feature in train_text at index 539 has shape: torch.Size([42, 768])
# Feature in train_text at index 540 has shape: torch.Size([40, 768])
# Feature in train_text at index 541 has shape: torch.Size([36, 768])
# Feature in train_text at index 542 has shape: torch.Size([9, 768])
# Feature in train_text at index 543 has shape: torch.Size([21, 768])
# Feature in train_text at index 544 has shape: torch.Size([23, 768])
# Feature in train_text at index 545 has shape: torch.Size([15, 768])
# Feature in train_text at index 546 has shape: torch.Size([44, 768])
# Feature in train_text at index 547 has shape: torch.Size([20, 768])
# Feature in train_text at index 548 has shape: torch.Size([31, 768])
# Feature in train_text at index 549 has shape: torch.Size([17, 768])
# Feature in train_text at index 550 has shape: torch.Size([10, 768])
# Feature in train_text at index 551 has shape: torch.Size([16, 768])
# Feature in train_text at index 552 has shape: torch.Size([7, 768])
# Feature in train_text at index 553 has shape: torch.Size([22, 768])
# Feature in train_text at index 554 has shape: torch.Size([33, 768])
# Feature in train_text at index 555 has shape: torch.Size([20, 768])
# Feature in train_text at index 556 has shape: torch.Size([15, 768])
# Feature in train_text at index 557 has shape: torch.Size([6, 768])
# Feature in train_text at index 558 has shape: torch.Size([11, 768])
# Feature in train_text at index 559 has shape: torch.Size([17, 768])
# Feature in train_text at index 560 has shape: torch.Size([14, 768])
# Feature in train_text at index 561 has shape: torch.Size([20, 768])
# Feature in train_text at index 562 has shape: torch.Size([22, 768])
# Feature in train_text at index 563 has shape: torch.Size([8, 768])
# Feature in train_text at index 564 has shape: torch.Size([49, 768])
# Feature in train_text at index 565 has shape: torch.Size([15, 768])
# Feature in train_text at index 566 has shape: torch.Size([8, 768])
# Feature in train_text at index 567 has shape: torch.Size([11, 768])
# Feature in train_text at index 568 has shape: torch.Size([26, 768])
# Feature in train_text at index 569 has shape: torch.Size([14, 768])
# Feature in train_text at index 570 has shape: torch.Size([7, 768])
# Feature in train_text at index 571 has shape: torch.Size([8, 768])
# Feature in train_text at index 572 has shape: torch.Size([11, 768])
# Feature in train_text at index 573 has shape: torch.Size([40, 768])
# Feature in train_text at index 574 has shape: torch.Size([20, 768])
# Feature in train_text at index 575 has shape: torch.Size([5, 768])
# Feature in train_text at index 576 has shape: torch.Size([27, 768])
# Feature in train_text at index 577 has shape: torch.Size([30, 768])
# Feature in train_text at index 578 has shape: torch.Size([15, 768])
# Feature in train_text at index 579 has shape: torch.Size([13, 768])
# Feature in train_text at index 580 has shape: torch.Size([28, 768])
# Feature in train_text at index 581 has shape: torch.Size([26, 768])
# Feature in train_text at index 582 has shape: torch.Size([10, 768])
# Feature in train_text at index 583 has shape: torch.Size([11, 768])
# Feature in train_text at index 584 has shape: torch.Size([9, 768])
# Feature in train_text at index 585 has shape: torch.Size([49, 768])
# Feature in train_text at index 586 has shape: torch.Size([11, 768])
# Feature in train_text at index 587 has shape: torch.Size([12, 768])
# Feature in train_text at index 588 has shape: torch.Size([17, 768])
# Feature in train_text at index 589 has shape: torch.Size([17, 768])
# Feature in train_text at index 590 has shape: torch.Size([18, 768])
# Feature in train_text at index 591 has shape: torch.Size([13, 768])
# Feature in train_text at index 592 has shape: torch.Size([18, 768])
# Feature in train_text at index 593 has shape: torch.Size([12, 768])
# Feature in train_text at index 594 has shape: torch.Size([49, 768])
# Feature in train_text at index 595 has shape: torch.Size([24, 768])
# Feature in train_text at index 596 has shape: torch.Size([33, 768])
# Feature in train_text at index 597 has shape: torch.Size([31, 768])
# Feature in train_text at index 598 has shape: torch.Size([18, 768])
# Feature in train_text at index 599 has shape: torch.Size([44, 768])
# Feature in train_text at index 600 has shape: torch.Size([19, 768])
# Feature in train_text at index 601 has shape: torch.Size([54, 768])
# Feature in train_text at index 602 has shape: torch.Size([27, 768])
# Feature in train_text at index 603 has shape: torch.Size([6, 768])
# Feature in train_text at index 604 has shape: torch.Size([23, 768])
# Feature in train_text at index 605 has shape: torch.Size([46, 768])
# Feature in train_text at index 606 has shape: torch.Size([12, 768])
# Feature in train_text at index 607 has shape: torch.Size([18, 768])
# Feature in train_text at index 608 has shape: torch.Size([37, 768])
# Feature in train_text at index 609 has shape: torch.Size([15, 768])
# Feature in train_text at index 610 has shape: torch.Size([20, 768])
# Feature in train_text at index 611 has shape: torch.Size([29, 768])
# Feature in train_text at index 612 has shape: torch.Size([17, 768])
# Feature in train_text at index 613 has shape: torch.Size([5, 768])
# Feature in train_text at index 614 has shape: torch.Size([15, 768])
# Feature in train_text at index 615 has shape: torch.Size([9, 768])
# Feature in train_text at index 616 has shape: torch.Size([10, 768])
# Feature in train_text at index 617 has shape: torch.Size([14, 768])
# Feature in train_text at index 618 has shape: torch.Size([23, 768])
# Feature in train_text at index 619 has shape: torch.Size([17, 768])
# Feature in train_text at index 620 has shape: torch.Size([15, 768])
# Feature in train_text at index 621 has shape: torch.Size([10, 768])
# Feature in train_text at index 622 has shape: torch.Size([16, 768])
# Feature in train_text at index 623 has shape: torch.Size([22, 768])
# Feature in train_text at index 624 has shape: torch.Size([23, 768])
# Feature in train_text at index 625 has shape: torch.Size([23, 768])
# Feature in train_text at index 626 has shape: torch.Size([9, 768])
# Feature in train_text at index 627 has shape: torch.Size([12, 768])
# Feature in train_text at index 628 has shape: torch.Size([14, 768])
# Feature in train_text at index 629 has shape: torch.Size([14, 768])
# Feature in train_text at index 630 has shape: torch.Size([24, 768])
# Feature in train_text at index 631 has shape: torch.Size([40, 768])
# Feature in train_text at index 632 has shape: torch.Size([53, 768])
# Feature in train_text at index 633 has shape: torch.Size([22, 768])
# Feature in train_text at index 634 has shape: torch.Size([23, 768])
# Feature in train_text at index 635 has shape: torch.Size([65, 768])
# Feature in train_text at index 636 has shape: torch.Size([17, 768])
# Feature in train_text at index 637 has shape: torch.Size([7, 768])
# Feature in train_text at index 638 has shape: torch.Size([42, 768])
# Feature in train_text at index 639 has shape: torch.Size([50, 768])
# Feature in train_text at index 640 has shape: torch.Size([12, 768])
# Feature in train_text at index 641 has shape: torch.Size([33, 768])
# Feature in train_text at index 642 has shape: torch.Size([17, 768])
# Feature in train_text at index 643 has shape: torch.Size([16, 768])
# Feature in train_text at index 644 has shape: torch.Size([32, 768])
# Feature in train_text at index 645 has shape: torch.Size([8, 768])
# Feature in train_text at index 646 has shape: torch.Size([33, 768])
# Feature in train_text at index 647 has shape: torch.Size([59, 768])
# Feature in train_text at index 648 has shape: torch.Size([22, 768])
# Feature in train_text at index 649 has shape: torch.Size([54, 768])
# Feature in train_text at index 650 has shape: torch.Size([21, 768])
# Feature in train_text at index 651 has shape: torch.Size([171, 768])
# Feature in train_text at index 652 has shape: torch.Size([24, 768])
# Feature in train_text at index 653 has shape: torch.Size([16, 768])
# Feature in train_text at index 654 has shape: torch.Size([31, 768])
# Feature in train_text at index 655 has shape: torch.Size([14, 768])
# Feature in train_text at index 656 has shape: torch.Size([15, 768])
# Feature in train_text at index 657 has shape: torch.Size([22, 768])
# Feature in train_text at index 658 has shape: torch.Size([33, 768])
# Feature in train_text at index 659 has shape: torch.Size([22, 768])
# Feature in train_text at index 660 has shape: torch.Size([31, 768])
# Feature in train_text at index 661 has shape: torch.Size([50, 768])
# Feature in train_text at index 662 has shape: torch.Size([15, 768])
# Feature in train_text at index 663 has shape: torch.Size([17, 768])
# Feature in train_text at index 664 has shape: torch.Size([16, 768])
# Feature in train_text at index 665 has shape: torch.Size([47, 768])
# Feature in train_text at index 666 has shape: torch.Size([13, 768])
# Feature in train_text at index 667 has shape: torch.Size([28, 768])
# Feature in train_text at index 668 has shape: torch.Size([29, 768])
# Feature in train_text at index 669 has shape: torch.Size([31, 768])
# Feature in train_text at index 670 has shape: torch.Size([49, 768])
# Feature in train_text at index 671 has shape: torch.Size([20, 768])
# Feature in train_text at index 672 has shape: torch.Size([14, 768])
# Feature in train_text at index 673 has shape: torch.Size([26, 768])
# Feature in train_text at index 674 has shape: torch.Size([17, 768])
# Feature in train_text at index 675 has shape: torch.Size([14, 768])
# Feature in train_text at index 676 has shape: torch.Size([6, 768])
# Feature in train_text at index 677 has shape: torch.Size([47, 768])
# Feature in train_text at index 678 has shape: torch.Size([8, 768])
# Feature in train_text at index 679 has shape: torch.Size([39, 768])
# Feature in train_text at index 680 has shape: torch.Size([20, 768])
# Feature in train_text at index 681 has shape: torch.Size([16, 768])
# Feature in train_text at index 682 has shape: torch.Size([16, 768])
# Feature in train_text at index 683 has shape: torch.Size([14, 768])
# Feature in train_text at index 684 has shape: torch.Size([62, 768])
# Feature in train_text at index 685 has shape: torch.Size([12, 768])
# Feature in train_text at index 686 has shape: torch.Size([18, 768])
# Feature in train_text at index 687 has shape: torch.Size([5, 768])
# Feature in train_text at index 688 has shape: torch.Size([20, 768])
# Feature in train_text at index 689 has shape: torch.Size([33, 768])
# Feature in train_text at index 690 has shape: torch.Size([27, 768])
# Feature in train_text at index 691 has shape: torch.Size([41, 768])
# Feature in train_text at index 692 has shape: torch.Size([24, 768])
# Feature in train_text at index 693 has shape: torch.Size([33, 768])
# Feature in train_text at index 694 has shape: torch.Size([31, 768])
# Feature in train_text at index 695 has shape: torch.Size([46, 768])
# Feature in train_text at index 696 has shape: torch.Size([40, 768])
# Feature in train_text at index 697 has shape: torch.Size([3, 768])
# Feature in train_text at index 698 has shape: torch.Size([13, 768])
# Feature in train_text at index 699 has shape: torch.Size([21, 768])
# Feature in train_text at index 700 has shape: torch.Size([26, 768])
# Feature in train_text at index 701 has shape: torch.Size([16, 768])
# Feature in train_text at index 702 has shape: torch.Size([110, 768])
# Feature in train_text at index 703 has shape: torch.Size([33, 768])
# Feature in train_text at index 704 has shape: torch.Size([20, 768])
# Feature in train_text at index 705 has shape: torch.Size([56, 768])
# Feature in train_text at index 706 has shape: torch.Size([41, 768])
# Feature in train_text at index 707 has shape: torch.Size([13, 768])
# ...
# Feature in test_text at index 3399 has shape: torch.Size([16, 768])
# Feature in test_text at index 3400 has shape: torch.Size([45, 768])
# Feature in test_text at index 3401 has shape: torch.Size([53, 768])
# Feature in test_text at index 3402 has shape: torch.Size([24, 768])
# Feature in test_text at index 3403 has shape: torch.Size([17, 768])
# Feature in test_text at index 3404 has shape: torch.Size([31, 768])
# Feature in test_text at index 3405 has shape: torch.Size([17, 768])
# Feature in test_text at index 3406 has shape: torch.Size([22, 768])
# Feature in test_text at index 3407 has shape: torch.Size([38, 768])
# Feature in test_text at index 3408 has shape: torch.Size([47, 768])
# Feature in test_text at index 3409 has shape: torch.Size([26, 768])
# Feature in test_text at index 3410 has shape: torch.Size([30, 768])
# Feature in test_text at index 3411 has shape: torch.Size([30, 768])
# Feature in test_text at index 3412 has shape: torch.Size([19, 768])
# Feature in test_text at index 3413 has shape: torch.Size([65, 768])
# Feature in test_text at index 3414 has shape: torch.Size([26, 768])
# Feature in test_text at index 3415 has shape: torch.Size([15, 768])
# Feature in test_text at index 3416 has shape: torch.Size([33, 768])
# Feature in test_text at index 3417 has shape: torch.Size([30, 768])
# Feature in test_text at index 3418 has shape: torch.Size([52, 768])
# Feature in test_text at index 3419 has shape: torch.Size([66, 768])
# Feature in test_text at index 3420 has shape: torch.Size([26, 768])
# Feature in test_text at index 3421 has shape: torch.Size([32, 768])
# Feature in test_text at index 3628 has shape: torch.Size([31, 768])
# Feature in test_text at index 3629 has shape: torch.Size([17, 768])
# Feature in test_text at index 3630 has shape: torch.Size([9, 768])
# Feature in test_text at index 3631 has shape: torch.Size([24, 768])
# Feature in test_text at index 3632 has shape: torch.Size([31, 768])
# Feature in test_text at index 3633 has shape: torch.Size([19, 768])

# %%
from torch.utils.data import Dataset, DataLoader
import torch
from torch.nn.utils.rnn import pad_sequence

class ThreeModal_Dataset(Dataset):
    def __init__(self, text_features, audio_features, labels):
        self.text_features = text_features
        self.audio_features = audio_features
        #self.vision_features = vision_features
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        text_features = self.text_features[idx]
        audio_features = self.audio_features[idx]
        #vision_features = self.vision_features[idx]
        labels = self.labels[idx]
        return text_features, audio_features, labels
    

def collate_fn(batch):
    # 从批次中分离音频特征、文本特征和标签
    text_features, audio_features, labels = zip(*batch)
    
    # 将音频特征和文本特征按照批次中最长的序列进行填充
    text_features_padded = pad_sequence(text_features, batch_first=True)    
    audio_features_padded = pad_sequence(audio_features, batch_first=True)
    #vision_features_padded = pad_sequence(vision_features, batch_first=True)    
    
    
    # 转换标签为张量
    labels = torch.tensor(labels)

    return text_features_padded, audio_features_padded, labels

# %%
train_Y_tensor = torch.tensor(train_Y)
valid_Y_tensor = torch.tensor(valid_Y)
test_Y_tensor = torch.tensor(test_Y)

# 创建Dataset实例
train_dataset = ThreeModal_Dataset(train_X_text, train_X_audio, train_Y_tensor)
valid_dataset = ThreeModal_Dataset(valid_X_text, valid_X_audio, valid_Y_tensor)
test_dataset = ThreeModal_Dataset(test_X_text, test_X_audio, test_Y_tensor)

# 创建DataLoader，使用自定义的collate_fn
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=2, collate_fn=collate_fn)
valid_loader = DataLoader(valid_dataset, batch_size=8, shuffle=False, num_workers=2, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers=2, collate_fn=collate_fn)

# %%
del train_X_text, train_X_audio, valid_X_text, valid_X_audio, valid_Y_tensor, test_X_text, test_X_audio, test_Y_tensor

# %%
# =========================
# Supervised Contrastive (SupCon) Teacher: Text↔Audio Cross-Attention
# 正样本 = 同源跨模态 + 同标签样本（同/异模态）
# Subcon 是来自文章 Supervised Contrastive Learning
# =========================
import os, math, random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt

# -------- Repro（SEED SETTING） --------
def set_seed(seed: int) -> None:
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True; torch.backends.cudnn.benchmark = False
SEED = 2025907 
set_seed(SEED)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
USE_AMP = True  # AMP 是 半精度 (float16/bfloat16) + 单精度 (float32) 混合训练，为了节约显存
#改成Flase有可能面临显存不足问题

# -------- Utility: Class-Balanced weights (Effective Number) --------
def compute_class_weights_from_loader(loader, num_classes=7, beta=0.999, device=None, label_index=2):
    """计算 Class-Balanced 权重；若不想用，传 None 给 CrossEntropyLoss 的 weight 即可。
    β 是控制“样本数增长时权重衰减的速度”。"""
    counts = np.zeros(num_classes, dtype=np.int64)
    for batch in loader:
        labels = batch[label_index] if len(batch) > label_index else batch[-1]
        counts += np.bincount(labels.detach().cpu().numpy(), minlength=num_classes)
    counts = np.maximum(counts, 1)#这行代码为了保证类别计数至少为 1，不会出现 0。
    effective_num = 1.0 - np.power(beta, counts)
    weights = (1.0 - beta) / effective_num
    weights = weights / weights.mean()
    w = torch.tensor(weights, dtype=torch.float32)
    return w.to(device) if device is not None else w

# -------- Attention Pooling (AMP-safe) --------
class _AttnPool(nn.Module):
    def __init__(self, d, drop=0.0):
        super().__init__()
        self.lin1 = nn.Linear(d, d)
        self.lin2 = nn.Linear(d, 1)
        self.drop = nn.Dropout(drop)
    def forward(self, x, lengths):  # x:[B,T,D], lengths:[B]
        h = torch.tanh(self.lin1(x))            # [B,T,D]
        w = self.lin2(h).squeeze(-1)            # [B,T]
        B, T, _ = x.size()
        mask = torch.arange(T, device=x.device)[None, :] >= lengths[:, None]  # True=pad

        # AI说：AMP 下用 FP32 + -inf 更稳——但我还没有很明白
        #-inf 是完全合法的浮点数，可以安全地喂给 softmax
        w32 = w.float()
        w32 = w32.masked_fill(mask, float('-inf'))
        a = torch.softmax(w32, dim=-1).to(x.dtype)  # [B,T] -> cast 回原 dtype

        # AI建议：若某样本长度为 0，兜底
        if (lengths == 0).any():
            zero_rows = (lengths == 0).nonzero(as_tuple=True)[0]
            a[zero_rows] = 0.0
            if T > 0:
                a[zero_rows, 0] = 1.0

        pooled = torch.bmm(a.unsqueeze(1), x).squeeze(1)  # [B,D]
        return self.drop(pooled), a

# -------- Positional Encoding --------
#和大多数的transformer一样
def sinusoidal_posenc(T: int, D: int, device):
    pe = torch.zeros(T, D, device=device)
    position = torch.arange(0, T, device=device, dtype=torch.float).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, D, 2, device=device, dtype=torch.float) * (-math.log(10000.0) / D))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # [T,D]

# -------- FFN（前馈网络）--------
class _FFN(nn.Module):
    def __init__(self, d, drop=0.1, mult=4):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(d, d*mult), nn.GELU(), nn.Dropout(drop),
            nn.Linear(d*mult, d), nn.Dropout(drop),
        )
    def forward(self, x): return self.net(x)

# -------- Model with SupCon --------
class TextAudioCrossAttentionClassifier(nn.Module):
    def __init__(self, text_dim, audio_dim, hidden_dim, num_heads,
                 dropout_rate=0.1, num_classes=7, proj_dim=128, modality_dropout_p=0.15,
                 temperature=0.07, same_utter_weight=2.0):
        super().__init__()
        self.dropout = nn.Dropout(dropout_rate)
        self.text_to_hidden  = nn.Linear(text_dim,  hidden_dim)
        self.audio_to_hidden = nn.Linear(audio_dim, hidden_dim)

        self.cross_text_q_audio_kv = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=num_heads, dropout=dropout_rate)
        self.cross_audio_q_text_kv = nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=num_heads, dropout=dropout_rate)

        self.ln_ta_1 = nn.LayerNorm(hidden_dim); self.ffn_ta = _FFN(hidden_dim, drop=dropout_rate); self.ln_ta_2 = nn.LayerNorm(hidden_dim)
        self.ln_at_1 = nn.LayerNorm(hidden_dim); self.ffn_at = _FFN(hidden_dim, drop=dropout_rate); self.ln_at_2 = nn.LayerNorm(hidden_dim)

        self.text_pool  = _AttnPool(hidden_dim, drop=dropout_rate)
        self.audio_pool = _AttnPool(hidden_dim, drop=dropout_rate)

        self.gate = nn.Sequential(nn.Linear(hidden_dim*2, hidden_dim), nn.ReLU(), nn.Linear(hidden_dim, 1), nn.Sigmoid())
        self.classifier = nn.Sequential(nn.Linear(hidden_dim * 2, hidden_dim), nn.ReLU(), nn.Dropout(dropout_rate), nn.Linear(hidden_dim, num_classes))

        self.proj_t = nn.Sequential(nn.Linear(hidden_dim, hidden_dim), nn.GELU(), nn.Linear(hidden_dim, proj_dim))
        self.proj_a = nn.Sequential(nn.Linear(hidden_dim, hidden_dim), nn.GELU(), nn.Linear(hidden_dim, proj_dim))
        self.modality_dropout_p = modality_dropout_p
        self.temperature = temperature
        self.same_utter_weight = same_utter_weight

    @staticmethod #静态方法，避免受实例状态影响
    def _infer_pad_mask(x):  # x:[B,T,D]
        return (x.abs().sum(dim=-1) == 0)

    def _supcon(self, z_t: torch.Tensor, z_a: torch.Tensor, labels: torch.Tensor) -> torch.Tensor:
        """监督式对比学习（SupCon）+ 同源跨模态加权。"""
        B = z_t.size(0); T = self.temperature
        Z = torch.cat([z_t, z_a], dim=0)          # [2B, D]
        Z = F.normalize(Z, dim=-1)
        y = labels.view(-1)
        y2 = torch.cat([y, y], dim=0)             # [2B]

        mask_pos = (y2.unsqueeze(0) == y2.unsqueeze(1)).float()  # 同标签
        eye = torch.eye(2*B, device=Z.device)
        mask_pos = mask_pos * (1.0 - eye)         # 去掉自身

        # 同源跨模态加权 (t_i ↔ a_i)
        W = torch.ones_like(mask_pos)
        idx = torch.arange(B, device=Z.device)
        W[idx, idx + B] = self.same_utter_weight
        W[idx + B, idx] = self.same_utter_weight

        # 相似度 + log-softmax（FP32，稳定）
        logits = torch.matmul(Z.float(), Z.float().t()) / T
        logits = logits - 1e9 * eye
        log_prob = logits - torch.logsumexp(logits, dim=1, keepdim=True)

        weighted_logp = W * mask_pos * log_prob
        pos_weight_sum = (W * mask_pos).sum(dim=1) + 1e-8
        loss_i = - (weighted_logp.sum(dim=1) / pos_weight_sum)

        valid = pos_weight_sum > 1e-7
        if valid.any():
            return loss_i[valid].mean()
        else:
            return logits.new_zeros(())

    def forward(self, text_features, audio_features, labels=None):
        # 1) 投影
        t = self.text_to_hidden(text_features)    # [B,Tt,H]
        a = self.audio_to_hidden(audio_features)  # [B,Ta,H]

        # 2) mask & 长度
        t_pad = self._infer_pad_mask(text_features); a_pad = self._infer_pad_mask(audio_features)
        len_t = (~t_pad).sum(dim=1); len_a = (~a_pad).sum(dim=1)

        # 3) 位置编码
        Bt, Tt, H = t.size(); Ba, Ta, _ = a.size()
        if Tt > 0: t = t + sinusoidal_posenc(Tt, H, t.device).unsqueeze(0)
        if Ta > 0: a = a + sinusoidal_posenc(Ta, H, a.device).unsqueeze(0)

        # 4) 双向 cross-attn（MHA 需要 [T,B,H]）
        tT = t.permute(1, 0, 2); aT = a.permute(1, 0, 2)
        taT,_ = self.cross_text_q_audio_kv(query=tT, key=aT, value=aT, key_padding_mask=a_pad)
        taT = taT + tT
        ta  = self.ln_ta_1(taT).permute(1,0,2); ta = self.ffn_ta(ta) + ta; ta = self.ln_ta_2(ta); ta = self.dropout(ta)

        atT,_ = self.cross_audio_q_text_kv(query=aT, key=tT, value=tT, key_padding_mask=t_pad)
        atT = atT + aT
        at  = self.ln_at_1(atT).permute(1,0,2); at = self.ffn_at(at) + at; at = self.ln_at_2(at); at = self.dropout(at)

        # 5) 池化 + 门控融合
        pooled_ta,_ = self.text_pool(ta, len_t)
        pooled_at,_ = self.audio_pool(at, len_a)

        if self.training and self.modality_dropout_p > 0:
            drop_t = (torch.rand(pooled_ta.size(0), 1, device=pooled_ta.device) > self.modality_dropout_p).float()
            drop_a = (torch.rand(pooled_at.size(0), 1, device=pooled_at.device) > self.modality_dropout_p).float()
            pooled_ta = pooled_ta * drop_t; pooled_at = pooled_at * drop_a

        alpha = self.gate(torch.cat([pooled_ta, pooled_at], dim=-1))
        fused = torch.cat([alpha * pooled_ta, (1 - alpha) * pooled_at], dim=-1)
        logits = self.classifier(fused)  # [B,C]

        # 6) 监督式对比（若无 labels 则退回 InfoNCE 同源对）
        if logits.size(0) > 1:
            z_t = F.normalize(self.proj_t(pooled_ta), dim=-1)
            z_a = F.normalize(self.proj_a(pooled_at), dim=-1)
            if labels is not None:
                c_loss = self._supcon(z_t, z_a, labels)
            else:
                sim = torch.matmul(z_t, z_a.t()) / 0.07
                targets = torch.arange(sim.size(0), device=sim.device)
                c_loss = 0.5 * (F.cross_entropy(sim, targets) + F.cross_entropy(sim.t(), targets))
        else:
            c_loss = logits.new_zeros(())
        return logits, c_loss

# %% [markdown]
# beta的设置来源于CVPR 2019《Class-Balanced Loss Based on Effective Number of Samples》 。
# β is a hyperparameter close to 1 (e.g., 0.9, 0.99, 0.999)。

# %%
# =========================
# Train loop (with CB-loss, AMP, warmup for SupCon)
# =========================

import os, random, numpy as np, torch
SEED = 20259072
def set_seed(seed: int):
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed(SEED)


def seed_worker(worker_id):
    worker_seed = (torch.initial_seed() ^ (worker_id + 1)) % 2**32
    np.random.seed(worker_seed); random.seed(worker_seed)
g_loader = torch.Generator(); g_loader.manual_seed(SEED)
# -------------------------

# 超参
TEXT_DIM, AUDIO_DIM, HIDDEN, HEADS, NUM_CLASSES = 768, 1024, 256, 8, 2
DROPOUT = 0.01
LR = 1e-4; WEIGHT_DECAY = 1e-2
STEP_SIZE = 5; GAMMA = 0.3
EPOCHS = 10
PATIENCE = 5
CKPT_PATH = 'acc2-textaudio_supcon_best' + str(SEED) +'.pth'

CONTRASTIVE_TARGET = 0.05
CONTRASTIVE_WARMUP_EPOCHS = 5
SAME_UTTER_WEIGHT = 2.0
TEMP = 0.07
GRAD_CLIP = 1.0

# —— 构建模型
model = TextAudioCrossAttentionClassifier(
    text_dim=TEXT_DIM, audio_dim=AUDIO_DIM, hidden_dim=HIDDEN, num_heads=HEADS,
    dropout_rate=DROPOUT, num_classes=NUM_CLASSES, proj_dim=128, modality_dropout_p=0.15,
    temperature=TEMP, same_utter_weight=SAME_UTTER_WEIGHT
).to(device)

# —— 类权重（可关）
use_cb_weight = True
if use_cb_weight:
    class_weights = compute_class_weights_from_loader(train_loader, num_classes=NUM_CLASSES, beta=0.999, device=device)
else:
    class_weights = None

criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = StepLR(optimizer, step_size=STEP_SIZE, gamma=GAMMA)

# ★ AMP 设置（修复 AttributeError）
USE_AMP = torch.cuda.is_available()
scaler = torch.cuda.amp.GradScaler(enabled=USE_AMP)

best_val_acc, bad_epochs = 0.0, 0
train_losses, valid_losses = [], []
train_accs, valid_accs = [], []

for epoch in range(EPOCHS):
    # ---- Train ----
    model.train()
    total_loss = total_correct = total_count = 0
    progress = min(1.0, (epoch + 1) / max(1, CONTRASTIVE_WARMUP_EPOCHS))
    contrastive_weight = CONTRASTIVE_TARGET * progress

    for batch in train_loader:
        if len(batch) >= 3:
            text_features, audio_features, labels = batch[:3]
        else:
            text_features, audio_features, labels = batch
        text_features = text_features.to(device); audio_features = audio_features.to(device); labels = labels.to(device)

        optimizer.zero_grad(set_to_none=True)
        with torch.cuda.amp.autocast(enabled=USE_AMP):
            logits, c_loss = model(text_features, audio_features, labels=labels)
            cls_loss = criterion(logits, labels)
            loss = cls_loss + contrastive_weight * c_loss

        # ★ 正确的 AMP 顺序：backward -> (unscale+clip) -> step -> update
        scaler.scale(loss).backward()
        if GRAD_CLIP is not None:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
        scaler.step(optimizer)
        scaler.update()

        bs = labels.size(0)
        total_loss   += loss.item() * bs
        total_correct+= (logits.argmax(dim=1) == labels).sum().item()
        total_count  += bs

    train_losses.append(total_loss / max(1, total_count))
    train_accs.append(total_correct / max(1, total_count))
    scheduler.step()

    # ---- Valid ----
    model.eval()
    v_loss = v_correct = v_count = 0
    with torch.no_grad():
        for batch in valid_loader:
            if len(batch) >= 3:
                text_features, audio_features, labels = batch[:3]
            else:
                text_features, audio_features, labels = batch
            text_features = text_features.to(device); audio_features = audio_features.to(device); labels = labels.to(device)

            with torch.cuda.amp.autocast(enabled=USE_AMP):
                logits, c_loss = model(text_features, audio_features, labels=labels)
                cls_loss = criterion(logits, labels)
                loss = cls_loss + contrastive_weight * c_loss

            bs = labels.size(0)
            v_loss   += loss.item() * bs
            v_correct+= (logits.argmax(dim=1) == labels).sum().item()
            v_count  += bs

    valid_losses.append(v_loss / max(1, v_count))
    valid_accs.append(v_correct / max(1, v_count))

    print(f"Epoch {epoch+1:02d} | TrainLoss {train_losses[-1]:.4f} Acc {train_accs[-1]:.4f} | "
          f"ValLoss {valid_losses[-1]:.4f} Acc {valid_accs[-1]:.4f} | w_contrast {contrastive_weight:.3f}")

    if valid_accs[-1] > best_val_acc:
        best_val_acc = valid_accs[-1]; bad_epochs = 0
        torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'random_seed': SEED,  # ★ NEW: 保存所用种子
            'config': {
                'TEMP': TEMP, 'SAME_UTTER_WEIGHT': SAME_UTTER_WEIGHT,
                'CONTRASTIVE_TARGET': CONTRASTIVE_TARGET,
                'CONTRASTIVE_WARMUP_EPOCHS': CONTRASTIVE_WARMUP_EPOCHS,
                'USE_AMP': USE_AMP
            }
        }, CKPT_PATH)
        print(f"  ✅ New best model saved to {CKPT_PATH} (acc={best_val_acc:.4f})")
    else:
        bad_epochs += 1
        if bad_epochs >= PATIENCE:
            print("  ⏹️ Early stopping triggered.")
            break

print(f"[Done] Best Val Acc: {best_val_acc:.4f}")

# ---- Plot curves ----
plt.figure(figsize=(11,4.2))
plt.subplot(1,2,1); plt.plot(train_losses, label='Train'); plt.plot(valid_losses, label='Valid'); plt.title('Loss'); plt.xlabel('Epoch'); plt.legend()
plt.subplot(1,2,2); plt.plot(train_accs, label='Train'); plt.plot(valid_accs, label='Valid'); plt.title('Accuracy'); plt.xlabel('Epoch'); plt.legend()
plt.tight_layout(); plt.show()
# Out:
# Epoch 01 | TrainLoss 0.3915 Acc 0.8400 | ValLoss 0.3707 Acc 0.8665 | w_contrast 0.010
#   ✅ New best model saved to acc2-textaudio_supcon_best20259072.pth (acc=0.8665)
# Epoch 02 | TrainLoss 0.3927 Acc 0.8544 | ValLoss 0.4119 Acc 0.8665 | w_contrast 0.020
# Epoch 03 | TrainLoss 0.4115 Acc 0.8596 | ValLoss 0.4445 Acc 0.8727 | w_contrast 0.030
#   ✅ New best model saved to acc2-textaudio_supcon_best20259072.pth (acc=0.8727)
# Epoch 04 | TrainLoss 0.4267 Acc 0.8642 | ValLoss 0.4234 Acc 0.8672 | w_contrast 0.040
# Epoch 05 | TrainLoss 0.4481 Acc 0.8652 | ValLoss 0.4733 Acc 0.8623 | w_contrast 0.050
# Epoch 06 | TrainLoss 0.4292 Acc 0.8726 | ValLoss 0.4811 Acc 0.8700 | w_contrast 0.050
# Epoch 07 | TrainLoss 0.4199 Acc 0.8781 | ValLoss 0.4906 Acc 0.8672 | w_contrast 0.050
# Epoch 08 | TrainLoss 0.4185 Acc 0.8803 | ValLoss 0.4847 Acc 0.8679 | w_contrast 0.050
#   ⏹️ Early stopping triggered.
# [Done] Best Val Acc: 0.8727

# %% [markdown]
# 关权重矩阵

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from scipy.stats import pearsonr
import numpy as np
import torch

# ==== 0) 一些小工具 ====
def _strip_module_prefix(sd: dict):
    return { (k[7:] if k.startswith('module.') else k): v for k, v in sd.items() }

def load_state_flex(model, ckpt_path, device):
    ckpt = torch.load(ckpt_path, map_location=device)
    if isinstance(ckpt, dict) and ('model_state_dict' in ckpt or 'state_dict' in ckpt):
        sd = ckpt.get('model_state_dict', ckpt.get('state_dict'))
    else:
        sd = ckpt
    sd = _strip_module_prefix(sd)
    missing, unexpected = model.load_state_dict(sd, strict=False)
    if missing:
        print('[eval/load] Missing keys (show up to 8):', list(missing)[:8])
    if unexpected:
        print('[eval/load] Unexpected keys (show up to 8):', list(unexpected)[:8])

# ==== 1) 模型一致 ====
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
USE_AMP = torch.cuda.is_available()  # 推理可选 autocast

model = TextAudioCrossAttentionClassifier(
    text_dim=768,
    audio_dim=1024,
    hidden_dim=256,
    num_heads=8,
    dropout_rate=0.01,
    num_classes=2
).to(device)

best_model_path = 'acc2-textaudio_supcon_best' + str(SEED) +'.pth'
load_state_flex(model, best_model_path, device)
model.eval()

# ==== 2) 推理收集部分 ====
true_ids, pred_ids = [], []

with torch.no_grad():
    for text_features, audio_features, labels in test_loader:
        text_features = text_features.to(device)
        audio_features = audio_features.to(device)
        labels = labels.to(device)

        # AI辅助纠错，兼容新签名；评估不需要对比损失，labels 传 None 即可
        with torch.cuda.amp.autocast(enabled=USE_AMP):
            logits, _ = model(text_features, audio_features, labels=None)
        pred = torch.argmax(logits, dim=1)

        pred_ids.extend(pred.cpu().numpy())
        true_ids.extend(labels.cpu().numpy())

true_ids = np.array(true_ids)
pred_ids = np.array(pred_ids)

# ==== 3) 通用分类指标（基于类别 id） ====
overall_acc = accuracy_score(true_ids, pred_ids)             # WA = overall acc
precision_w = precision_score(true_ids, pred_ids, average='weighted', zero_division=0)
recall_w    = recall_score(true_ids, pred_ids, average='weighted', zero_division=0)
f1_w        = f1_score(true_ids, pred_ids, average='weighted', zero_division=0)

cm = confusion_matrix(true_ids, pred_ids)
with np.errstate(divide='ignore', invalid='ignore'):
    per_class_acc = np.diag(cm) / np.maximum(cm.sum(axis=1), 1)  # 防除零
    per_class_acc = np.nan_to_num(per_class_acc)
ua = per_class_acc.mean()    # UA = macro-Acc
wa = overall_acc             # WA = overall acc（样本均权）

# ==== 4) 仅在 7 类（0..6）时，把 id 映射到 [-3..3] 再算 MAE / Pearson ====
mae = None
corr = None
is_7class = (len(np.unique(true_ids)) == 7) and (true_ids.min() >= 0) and (true_ids.max() <= 6)
if is_7class:
    default_bins = np.array([-3, -2, -1, 0, 1, 2, 3], dtype=float)
    bins_true = default_bins[true_ids]
    bins_pred = default_bins[pred_ids]
    mae = float(np.mean(np.abs(bins_true - bins_pred)))
    try:
        corr, _ = pearsonr(bins_true, bins_pred)
    except Exception:
        corr = 0.0

# ==== 5) 打印 ====
n_class = len(np.unique(true_ids))
print(f"Num classes: {n_class}")
print(f"WA (Overall Acc): {wa:.4f}")
print(f"UA (Macro Acc):   {ua:.4f}")
print(f"F1 (Weighted):    {f1_w:.4f}")
print(f"Precision (W):    {precision_w:.4f}")
print(f"Recall (W):       {recall_w:.4f}")
# Out:
# Num classes: 2
# WA (Overall Acc): 0.8685
# UA (Macro Acc):   0.8510
# F1 (Weighted):    0.8672
# Precision (W):    0.8677
# Recall (W):       0.8685
